# %% [markdown]
# **Objetivos da aula:**
#
# *   Filtro negativo de imagem
# *   Recorte da imagem
# *   Seguimentação por pixel

# %%
# %matplotlib inline
# Importando a biblioteca OpenCV
import cv2

#import a biblioteca Numpy
import numpy as np

from matplotlib import pyplot as plt


print ("OpenCV Versão : %s " % cv2.__version__)
# Out:
# OpenCV Versão : 4.11.0

# %%
# !wget "https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/cogumelo.png" /content
# !wget "https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/droneinvertido.jpg" /content
# !wget "https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/drone.jpg" /content
# !wget "https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/droneinvertido.jpg" /content
# !wget "https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/goku.jpg" /content
# !wget "https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/gokuinvertido.jpg" /content
# !wget "https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/cogumelo.png" /content
# Out:
# --2025-02-20 12:38:24--  https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/cogumelo.png
# 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8003::154, ....
# Conectando-se a raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... conectado.
# 200 OKisição HTTP foi enviada, aguardando resposta...
# Tamanho: 48478 (47K) [image/png]
# Salvando em: “cogumelo.png”
#
# cogumelo.png        100%[===================>]  47,34K  --.-KB/s    em 0,004s
#
# 2025-02-20 12:38:24 (12,4 MB/s) - “cogumelo.png” salvo [48478/48478]
#
# Prepended http:// to '/content'
# http:///content: O nome de máquina é inválido.
# FINALIZADO --2025-02-20 12:38:24--
# Tempo total decorrido: 0,4s
# Baixados: 1 arquivos, 47K em 0,004s (12,4 MB/s)
# --2025-02-20 12:38:24--  https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/droneinvertido.jpg
# 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8003::154, ....
# Conectando-se a raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... conectado.
# 200 OKisição HTTP foi enviada, aguardando resposta...
# Tamanho: 52937 (52K) [image/jpeg]
# Salvando em: “droneinvertido.jpg”
#
# droneinvertido.jpg  100%[===================>]  51,70K  --.-KB/s    em 0,007s
#
# 2025-02-20 12:38:25 (6,80 MB/s) - “droneinvertido.jpg” salvo [52937/52937]
#
# Prepended http:// to '/content'
# http:///content: O nome de máquina é inválido.
# FINALIZADO --2025-02-20 12:38:25--
# Tempo total decorrido: 0,4s
# Baixados: 1 arquivos, 52K em 0,007s (6,80 MB/s)
# --2025-02-20 12:38:25--  https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/drone.jpg
# 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8003::154, ....
# Conectando-se a raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... conectado.
# 200 OKisição HTTP foi enviada, aguardando resposta...
# Tamanho: 37505 (37K) [image/jpeg]
# Salvando em: “drone.jpg”
#
# drone.jpg           100%[===================>]  36,63K  --.-KB/s    em 0,001s
#
# 2025-02-20 12:38:25 (30,0 MB/s) - “drone.jpg” salvo [37505/37505]
#
# Prepended http:// to '/content'
# http:///content: O nome de máquina é inválido.
# FINALIZADO --2025-02-20 12:38:25--
# Tempo total decorrido: 0,3s
# Baixados: 1 arquivos, 37K em 0,001s (30,0 MB/s)
# --2025-02-20 12:38:25--  https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/droneinvertido.jpg
# Resolvendo raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8003::154, ...
# Conectando-se a raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... conectado.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 52937 (52K) [image/jpeg]
# Salvando em: “droneinvertido.jpg.1”
#
# droneinvertido.jpg. 100%[===================>]  51,70K  --.-KB/s    em 0,007s
#
# 2025-02-20 12:38:25 (6,97 MB/s) - “droneinvertido.jpg.1” salvo [52937/52937]
#
# Prepended http:// to '/content'
# http:///content: O nome de máquina é inválido.
# FINALIZADO --2025-02-20 12:38:25--
# Tempo total decorrido: 0,06s
# Baixados: 1 arquivos, 52K em 0,007s (6,97 MB/s)
# --2025-02-20 12:38:26--  https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/goku.jpg
# Resolvendo raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8003::154, ...
# Conectando-se a raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... conectado.
# 200 OKisição HTTP foi enviada, aguardando resposta...
# Tamanho: 113004 (110K) [image/jpeg]
# Salvando em: “goku.jpg”
#
# goku.jpg            100%[===================>] 110,36K  --.-KB/s    em 0,01s
#
# 2025-02-20 12:38:26 (8,99 MB/s) - “goku.jpg” salvo [113004/113004]
#
# Prepended http:// to '/content'
# http:///content: O nome de máquina é inválido.
# FINALIZADO --2025-02-20 12:38:26--
# Tempo total decorrido: 0,3s
# Baixados: 1 arquivos, 110K em 0,01s (8,99 MB/s)
# --2025-02-20 12:38:26--  https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/gokuinvertido.jpg
# 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8003::154, ....
# Conectando-se a raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... conectado.
# 200 OKisição HTTP foi enviada, aguardando resposta...
# Tamanho: 154233 (151K) [image/jpeg]
# Salvando em: “gokuinvertido.jpg”
#
# gokuinvertido.jpg   100%[===================>] 150,62K  --.-KB/s    em 0,02s
#
# 2025-02-20 12:38:26 (9,25 MB/s) - “gokuinvertido.jpg” salvo [154233/154233]
#
# Prepended http:// to '/content'
# http:///content: O nome de máquina é inválido.
# FINALIZADO --2025-02-20 12:38:26--
# Tempo total decorrido: 0,3s
# Baixados: 1 arquivos, 151K em 0,02s (9,25 MB/s)
# --2025-02-20 12:38:27--  https://raw.githubusercontent.com/arnaldojr/cognitivecomputing/master/material/aulas/PDI/lab02/cogumelo.png
# Resolvendo raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8003::154, ...
# Conectando-se a raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... conectado.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 48478 (47K) [image/png]
# Salvando em: “cogumelo.png.1”
#
# cogumelo.png.1      100%[===================>]  47,34K  --.-KB/s    em 0,007s
#
# 2025-02-20 12:38:27 (6,59 MB/s) - “cogumelo.png.1” salvo [48478/48478]
#
# Prepended http:// to '/content'
# http:///content: O nome de máquina é inválido.
# FINALIZADO --2025-02-20 12:38:27--
# Tempo total decorrido: 0,06s
# Baixados: 1 arquivos, 47K em 0,007s (6,59 MB/s)

# %% [markdown]
# ## Filtro negativo (Inverte imagem)
#
# Para aplicar um filtro negativo precisamos inverter os seus valores, ou seja, em uma imagem binária realizamos a troca de 0 pra 1 e de 1 para 0 para cada pixel da imagem.

# %%
import cv2
imagem = cv2.imread("cogumelo.png")
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

plt.imshow(image, interpolation="none", cmap="gray")
plt.show()

# %%
import cv2
imagem = cv2.imread("cogumelo.png")
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

for y in range(0, image.shape[0]):
  for x in range(0, image.shape[1]):
    ##### aqui eu inverto o valor do pixel
    if image[y, x] == 255:
      image[y,x] = 0
    else:
      image[y,x] = 255

plt.imshow(image, interpolation="none", cmap="gray")
plt.show()

# %% [markdown]
# ## Desafio 1
#
# Faça uma implementação que inverte as cores de uma imagem em escala de cinza, com valores que vão de 0 ate 255.
# dica: a forma explicita de fazer uma inversãão é: a = 255 - a

# %%
# implemente aqui sua solução

import cv2
imagem = cv2.imread("cogumelo.png")
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

for y in range(0, image.shape[0]):
  for x in range(0, image.shape[1]):
    ##### aqui eu inverto o valor do pixel
    image[y,x] = 255 - image[y,x]
    if image[y,x] > 100: #se o tom de cinza for acima de 100 fica 255(branco)
      image[y,x] = 255

plt.imshow(image, interpolation="none", cmap="gray")
plt.show()

# %% [markdown]
# ## Desafio 2
#
# Faça o mesmo par uma imagem colorida, realize a inversão de cores dos canais R, G e B.
#
# o resultado deve ser parecido com a imagem abaixo: ![droneinvertido.jpg](data:image/jpeg;base64,...)

# %%
# Implemente aqui sua solução

import cv2
imagem = cv2.imread("drone.png")
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)

for y in range(0, image.shape[0]):
  for x in range(0, image.shape[1]):
    ##### aqui eu inverto o valor do pixel
    image[y,x] = 255 - image[y,x]
    if image[y,x] > 100: #se o tom de cinza for acima de 100 fica 255(branco)
      image[y,x] = 255

plt.imshow(image, interpolation="none", cmap="gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-4a69a3ea6e1f> in <cell line: 0>()
#       3 import cv2
#       4 imagem = cv2.imread("drone.png")
# ----> 5 image = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
#       6
#       7 # for y in range(0, image.shape[0]):
#
# error: OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# ## Recorte da imagem (crop)
#
# O recorte de uma parte da imagem, ou crop, consiste em extrair da imagem uma região de interresse (ROI).

# %%
import cv2
imagem = cv2.imread("drone.jpg")
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

plt.imshow(image, interpolation="none")

plt.show()

# %%
image2 = image.copy()

#crop_img = img[y:y+h, x:x+w]
image2 = image[50:250,580:950]

plt.imshow(image2, interpolation="none", cmap="gray")
plt.show()

# %% [markdown]
# ## Desafio3
#
# Ajude o nosso sayajin!!
#
# ![goku.jpg](data:image/jpeg;base64,...)
#
# A imagem foi dividida em 4 quadrantes aleatorios e precisamos organizar essa bagunça. Faça a reconstrução da imagem nas posições corretas.
#
# Dica: Crie uma copia da imagem original (img2 = img.copy()), faça um crop da imagem 4 partes (crop1, crop2, crop3, crop4), junte as partes cortadas na ordem correta na img2. no final Salve a imagem (cv2.imwrite())

# %%
import cv2
imagem = cv2.imread("gokuinvertido.jpg")
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

altura = image.shape[0]
largura = image.shape[1]

print("altura: {} largura: {}".format(altura, largura))

plt.imshow(image, interpolation="none")

plt.show()

# para salvar imagem
#cv2.imwrite("gokunormal.jpg", cv2.cvtColor(image2, cv2.COLOR_RGB2BGR))
# Out:
# altura: 720 largura: 1280

# %%
#implemente sua solução

# %% [markdown]
# ## Seguimentação de imagens
#
# Agora que sabemos como manipular pixel e como alterar seu valor e sua posição. Podemos fazer atividades mais complexas como conseguir reaalizar a seguimentação de algum objeto ou item da imagem (video), Como na imagem abaixo.

# %% [markdown]
# ## Desafio 4
#
# De forma intuitiva realize algumas mudanças no código e veja o efeito que causa na imagem. Este exercio é apenas um aperitivo de algumas tecnicas que vamos estudar na proxima aula.

# %%
# Entenda o codigo e faça as alterações que achar necessárias
import cv2
imagem = cv2.imread("drone.jpg")
image = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)
print(image.shape)

for y in range(0, image.shape[0]):
  for x in range(0, image.shape[1]):
    if image[y,x,1] > 170 :
      image[y,x]= (255,255,255)


plt.imshow(image, interpolation="none")
plt.show()
# Out:
# (420, 1120, 3)

# %% [markdown]
# ## Desafio 5
#
# Vamos tentar fazer o contrario, vamos tentar filtar o fundo da imagem sem o drone

# %%
# Implemente seu código aqui
